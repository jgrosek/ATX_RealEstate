# %%
from homeharvest import scrape_property
import pandas as pd

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)        # Auto-adjust display width to fit console
pd.set_option('display.max_colwidth', 50)   # Limit max column width to 50 characters

# %% [markdown]
# # scrapes all 3 sites by default
# scrape_property(
#     location="Austin",
#     listing_type="for_rent"
# )

# %%
# check rentals
rent = scrape_property(
    location="Austin",
    ##site_name=["redfin","zillow"],
    listing_type="for_rent"
)
rent.to_csv('austin-rentals.csv',header=True)

# check sales
buy = scrape_property(
    location="Austin",
    ##site_name=["redfin","zillow"],
    listing_type="for_sale"
)
buy.to_csv('austin-purchases.csv',header=True)

# %%
rent.head()
# Out:
#                                         property_url   mls   mls_id    status  \
# 0  https://www.realtor.com/realestateandhomes-det...  AUTX  3398317  FOR_RENT
# 1  https://www.realtor.com/realestateandhomes-det...  AUTX  7871737  FOR_RENT
# 2  https://www.realtor.com/realestateandhomes-det...  AUTX  1359159  FOR_RENT
# 3  https://www.realtor.com/realestateandhomes-det...  AUTX  6993174  FOR_RENT
# 4  https://www.realtor.com/realestateandhomes-det...  AUTX  4734737  FOR_RENT
#
#            style             street      unit    city state zip_code beds  \
# 0  SINGLE_FAMILY   6105 Roderick Dr      None  Austin    TX    78724    3
# 1  SINGLE_FAMILY  3303 Crownover St      None  Austin    TX    78725    4
# 2         CONDOS      360 Nueces St  Apt 3109  Austin    TX    78701    2
# 3  SINGLE_FAMILY        1406 2nd St    Unit 1  Austin    TX    78702    3
# 4  SINGLE_FAMILY     8515 Putnam Dr      None  Austin    TX    78757    3
#
#   full_baths half_baths  sqft year_built days_on_mls list_price   list_date  \
# 0          2       None  1725       2021        None       2100  2023-10-19
# 1          2       None  1448       2005        None       1995  2023-10-19
# 2          2       None  1244       2008        None       4500  2023-10-19
# 3          2       None  1387       2008           0       4750  2023-10-18
# 4          2       None  1141       1965           0       1795  2023-10-18
#
#   sold_price last_sold_date lot_sqft price_per_sqft   latitude  longitude  \
# 0       None           None     5750              1  30.262033 -97.583739
# 1       None           None     4312              1  30.230367 -97.587809
# 2       None           None      174              4  30.267658 -97.749619
# 3       None           None     6229              3  30.260099 -97.729591
# 4       None           None     7187              2  30.363414 -97.721684
#
#   stories hoa_fee parking_garage
# 0       1       0              2
# 1       1       0              1
# 2       1    None              2
# 3       1       0           None
# 4       1       0              1

# %%
# Group the data by "property_type" and count the occurrences of each type
property_type_counts = buy.groupby('style').size().reset_index(name='count')

# Sort the DataFrame in descending order by the "count" column
property_type_counts = property_type_counts.sort_values(by='count', ascending=False)

# Calculate the total count of all property types
total_count = property_type_counts['count'].sum()

# Add a new column with the percentage of each property type
property_type_counts['percentage'] = (property_type_counts['count'] / total_count) * 100

# Round the "percentage" column to 1 decimal point
property_type_counts['percentage'] = property_type_counts['percentage'].round(1)

print(property_type_counts)
# Out:
#            style  count  percentage
# 5  SINGLE_FAMILY   3297        66.2
# 0         CONDOS    935        18.8
# 2           LAND    449         9.0
# 4   MULTI_FAMILY    121         2.4
# 6      TOWNHOMES    111         2.2
# 3         MOBILE     37         0.7
# 1           FARM     30         0.6

# %%
# Group the data by "property_type" and count the occurrences of each type
rental_counts = rent.groupby('style').size().reset_index(name='count')

# Sort the DataFrame in descending order by the "count" column
rental_counts = rental_counts.sort_values(by='count', ascending=False)

# Calculate the total count of all property types
total_rental_count = rental_counts['count'].sum()

# Add a new column with the percentage of each property type
rental_counts['percentage'] = (rental_counts['count'] / total_count) * 100

# Round the "percentage" column to 1 decimal point
rental_counts['percentage'] = rental_counts['percentage'].round(1)

print(rental_counts)
# Out:
#             style  count  percentage
# 0       APARTMENT   2664        53.5
# 7   SINGLE_FAMILY   2111        42.4
# 1          CONDOS    898        18.0
# 3  DUPLEX_TRIPLEX    416         8.4
# 8       TOWNHOMES    133         2.7
# 2  CONDO_TOWNHOME     52         1.0
# 4          MOBILE      7         0.1
# 6           OTHER      4         0.1
# 5    MULTI_FAMILY      3         0.1
